# %% [markdown]
# <a href="https://colab.research.google.com/github/kiryu-3/Prmn2023/blob/main/Python/Python_Basic/question/PythonBasic_2_Question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 第2章 課題

# %% [markdown]
# ## 課題1

# %% [markdown]
# for文を使って、以下のように出力してください

# %% [markdown]
# ![oSFeQoX.png](https://i.imgur.com/oSFeQoX.png)

# %%
# 入力用
for i in range(1,5):
  print(' '*(4-i)+'*'*(2*i-1))
# Out:
#    *
#   ***
#  *****
# *******

# %% [markdown]
# ## 課題2

# %% [markdown]
# 課題1の場合を`n=4`として、nを自分で設定して出力できるようにしてください

# %% [markdown]
# ＜例＞ n=5の場合
# ![o5NjugQ.png](https://imgur.com/o5NjugQ.png)

# %%
# 入力用
n=int(input())
for i in range(1,n+1):
  print(' '*(n-i)+'*'*(2*i-1))
# Out:
# 3
#   *
#  ***
# *****

# %% [markdown]
# ## 課題3

# %% [markdown]
# for文を使って、以下のように出力してください

# %% [markdown]
# ![oSirXec.png](https://imgur.com/oSirXec.png)

# %%
# 入力用
for i in range(1,5):
  print(' '*(4-i)+'*'*(2*i-1))
for i in range(3,0,-1):
  print(' '*(4-i)+'*'*(2*i-1))
# Out:
#    *
#   ***
#  *****
# *******
#  *****
#   ***
#    *

# %% [markdown]
# ## 課題4

# %% [markdown]
# 課題3の場合を`n=4`として、nを自分で設定して出力できるようにしてください

# %% [markdown]
# ＜例＞ n=5の場合
#
# ![my4J17V.png](https://i.imgur.com/my4J17V.png)

# %%
# 入力用
n=int(input())
for i in range(1,n+1):
  print(' '*(n-i)+'*'*(2*i-1))
for i in range(n-1,0,-1):
  print(' '*(n-i)+'*'*(2*i-1))
# Out:
# 5
#     *
#    ***
#   *****
#  *******
# *********
#  *******
#   *****
#    ***
#     *

# %% [markdown]
# ## 課題5

# %% [markdown]
# for文を使って、以下のように出力してください

# %% [markdown]
# ![vDUi5eM.png](https://imgur.com/vDUi5eM.png)

# %%
# 入力用
for i in range(1,5):
  if(i==4):
    print(' '*(4-i)+'*'*(2*i-1)+' '*(5-(2*(i-1)))+'*'*(2*i-2))
  else:
    print(' '*(4-i)+'*'*(2*i-1)+' '*(5-(2*(i-1)))+'*'*(2*i-1))
for i in range(3,0,-1):
  print(' '*(4-i)+'*'*(2*i-1)+' '*(5-(2*(i-1)))+'*'*(2*i-1))
# Out:
#    *     *
#   ***   ***
#  ***** *****
# *************
#  ***** *****
#   ***   ***
#    *     *

# %% [markdown]
# ## 課題6

# %% [markdown]
# 課題5の場合を`n=4`として、nを自分で設定して出力できるようにしてください

# %% [markdown]
# ＜例＞ n=5の場合
#
# ![udkVlYG.png](https://imgur.com/udkVlYG.png)

# %%
# 入力用
n=int(input())
for i in range(1,n+1):
  if(i==n):
    print(' '*(n-i)+'*'*(2*i-1)+' '*(2*n-3-(2*(i-1)))+'*'*(2*i-2))
  else:
    print(' '*(n-i)+'*'*(2*i-1)+' '*(2*n-3-(2*(i-1)))+'*'*(2*i-1))
for i in range(n-1,0,-1):
  print(' '*(n-i)+'*'*(2*i-1)+' '*(2*n-3-(2*(i-1)))+'*'*(2*i-1))
# Out:
# 5
#     *       *
#    ***     ***
#   *****   *****
#  ******* *******
# *****************
#  ******* *******
#   *****   *****
#    ***     ***
#     *       *

# %% [markdown]
# ## 課題7

# %% [markdown]
# for文を使って、以下のように出力してください

# %% [markdown]
# ![IuP0M16.png](https://imgur.com/IuP0M16.png)

# %%
# 入力用
for i in range(1,5):
  if(i==4):
    print(' '*(4-i)+'*'*(2*i-1)+' '*(5-(2*(i-1)))+'*'*(2*i-2))
  else:
    print(' '*(4-i)+'*'*(2*i-1)+' '*(5-(2*(i-1)))+'*'*(2*i-1))
for i in range(3,1,-1):
  print(' '*(4-i)+'*'*(2*i-1)+' '*(5-(2*(i-1)))+'*'*(2*i-1))
for i in range(1,5):
  if(i==4):
    print(' '*(4-i)+'*'*(2*i-1)+' '*(5-(2*(i-1)))+'*'*(2*i-2))
  else:
    print(' '*(4-i)+'*'*(2*i-1)+' '*(5-(2*(i-1)))+'*'*(2*i-1))
for i in range(3,0,-1):
  print(' '*(4-i)+'*'*(2*i-1)+' '*(5-(2*(i-1)))+'*'*(2*i-1))
# Out:
#    *     *
#   ***   ***
#  ***** *****
# *************
#  ***** *****
#   ***   ***
#    *     *
#   ***   ***
#  ***** *****
# *************
#  ***** *****
#   ***   ***
#    *     *

# %% [markdown]
# ## 課題8

# %% [markdown]
# 課題7の場合を`n=4`として、nを自分で設定して出力できるようにしてください

# %% [markdown]
# ＜例＞ n=5の場合
#
# ![AlTnu1k.png](https://imgur.com/AlTnu1k.png)

# %%
# 入力用
n=int(input())
for i in range(1,n+1):
  if(i==n):
    print(' '*(n-i)+'*'*(2*i-1)+' '*(2*n-3-(2*(i-1)))+'*'*(2*i-2))
  else:
    print(' '*(n-i)+'*'*(2*i-1)+' '*(2*n-3-(2*(i-1)))+'*'*(2*i-1))
for i in range(n-1,1,-1):
  print(' '*(n-i)+'*'*(2*i-1)+' '*(2*n-3-(2*(i-1)))+'*'*(2*i-1))
for i in range(1,n+1):
  if(i==n):
    print(' '*(n-i)+'*'*(2*i-1)+' '*(2*n-3-(2*(i-1)))+'*'*(2*i-2))
  else:
    print(' '*(n-i)+'*'*(2*i-1)+' '*(2*n-3-(2*(i-1)))+'*'*(2*i-1))
for i in range(n-1,0,-1):
  print(' '*(n-i)+'*'*(2*i-1)+' '*(2*n-3-(2*(i-1)))+'*'*(2*i-1))
# Out:
# 5
#     *       *
#    ***     ***
#   *****   *****
#  ******* *******
# *****************
#  ******* *******
#   *****   *****
#    ***     ***
#     *       *
#    ***     ***
#   *****   *****
#  ******* *******
# *****************
#  ******* *******
#   *****   *****
#    ***     ***
#     *       *
